# %%
from spacepy import pycdf
import pandas as pd
from datetime import datetime
import numpy as np
import datetime as dt

# %%
cdf = pycdf.CDF('ac_h0s_mfi_20120122000004_20120122235948_cdaweb.cdf')
print(cdf['Epoch'])
print(cdf['Epoch'][...])
# Out:
# CDF_EPOCH [5400]
# [datetime.datetime(2012, 1, 22, 0, 0, 4)
#  datetime.datetime(2012, 1, 22, 0, 0, 20)
#  datetime.datetime(2012, 1, 22, 0, 0, 36) ...
#  datetime.datetime(2012, 1, 22, 23, 59, 16)
#  datetime.datetime(2012, 1, 22, 23, 59, 32)
#  datetime.datetime(2012, 1, 22, 23, 59, 48)]

# %%
ace_mfi = pd.read_csv('AC_H0_MFI_3649384.csv', header=0, parse_dates=[0], names=['Date', 'Bx', 'By', 'Bz', 'X', 'Y', 'Z'])
B = ace_mfi[['Bx', 'By', 'Bz']].to_numpy()

# %%
cdf_ace = pycdf.CDF('ac_mfi_fromcsv4.cdf','')
tt2000_datetimes = ace_mfi['Date'][...]
epoch_values = [dt.timestamp() for dt in tt2000_datetimes]
cdf_ace['Epoch'] = epoch_values
cdf_ace['B'] = B.astype(np.float32)
cdf_ace.attrs['Author'] = 'Espen Fredrick'
cdf_ace.attrs['CreateDate'] = datetime.now()
cdf_ace['B'].attrs['units'] = 'nT'
cdf_ace.close()
# Out:
# ---------------------------------------------------------------------------
# CDFError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cdf_ace = pycdf.CDF('ac_mfi_fromcsv4.cdf','')
#       2 tt2000_datetimes = ace_mfi['Date'][...]
#       3 epoch_values = [dt.timestamp() for dt in tt2000_datetimes]
#
# File ~\anaconda3\envs\Research_Espen\Lib\site-packages\spacepy\pycdf\__init__.py:1650, in CDF.__init__(self, pathname, masterpath, create, readonly, encoding)
#    1648     self._check_enc()
#    1649 else:
# -> 1650     self._create()
#    1651     self._check_enc()
#    1652 lib.call(const.SELECT_, const.CDF_zMODE_, ctypes.c_long(2))
#
# File ~\anaconda3\envs\Research_Espen\Lib\site-packages\spacepy\pycdf\__init__.py:1849, in CDF._create(self)
#    1834 def _create(self):
#    1835     """Creates (and opens) a new CDF file
#    1836
#    1837     Created at ``pathname``.
#    (...)   1847         `pycdf.CDF` constructor.
#    1848     """
# -> 1849     lib.call(const.CREATE_, const.CDF_, self.pathname, ctypes.c_long(0),
#    1850                           (ctypes.c_long * 1)(0), ctypes.byref(self._handle))
#    1851     self._opened = True
#
# File ~\anaconda3\envs\Research_Espen\Lib\site-packages\spacepy\pycdf\__init__.py:514, in Library.call(self, *args, **kwargs)
#     510     return self.check_status(self._library.CDFlib(
#     511         *(args + (const.NULL_, ))
#     512         ), kwargs['ignore'])
#     513 else:
# --> 514     return self.check_status(self._library.CDFlib(
#     515         *(args + (const.NULL_, ))
#     516         ))
#
# File ~\anaconda3\envs\Research_Espen\Lib\site-packages\spacepy\pycdf\__init__.py:467, in Library.check_status(self, status, ignore)
#     465     return status
#     466 if status < const.CDF_WARN:
# --> 467     raise CDFError(status)
#     468 else:
#     469     warning = CDFWarning(status)
#
# CDFError: CDF_EXISTS: The CDF named already exists.

# %%
cdf_ace = pycdf.CDF('ac_mfi_fromcsv1.cdf')
print(cdf)
print('_________________')
print(cdf_ace)
# Out:
# BGSM: CDF_FLOAT [5400, 3]
# Epoch: CDF_EPOCH [5400]
# SC_pos_GSM: CDF_FLOAT [5400, 3]
# cartesian: CDF_CHAR*11 [3] NRV
# metavar0: CDF_CHAR*8 [3] NRV
# metavar1: CDF_CHAR*9 [3] NRV
# _________________
# B: CDF_FLOAT [5400, 3]
# Epoch: CDF_FLOAT [5400]

# %%
tt2000_datetimes = ace_mfi['Date'][...]
epoch_values = [dt.timestamp() for dt in tt2000_datetimes]
#print(tt2000_datetimes)
A = str(tt2000_datetimes)
print(type(A[2]))
print(A[1])
# Out:
# [1.3271904e+09 1.3271904e+09 1.3271904e+09 ... 1.3272768e+09 1.3272768e+09
#  1.3272768e+09]
